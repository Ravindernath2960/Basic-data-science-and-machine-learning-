# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as  plt

# %%
data = pd.read_csv('germany.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        0
# ...

# %%
data.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
import numpy as np
i = data[data['BloodPressure'] == 0].index
data = data.drop(i)
i
# Out:
# Int64Index([   2,   12,   49,   60,   78,   81,  172,  193,  222,  261,  266,
#              269,  300,  332,  336,  347,  357,  426,  430,  435,  453,  468,
#              484,  494,  522,  533,  535,  589,  601,  604,  619,  643,  697,
#              703,  706,  770,  802,  806,  817,  827,  896,  900,  905,  923,
#              938,  954,  964,  990,  992, 1046, 1058, 1061, 1076, 1100, 1154,
#             1160, 1163, 1227, 1330, 1351, 1380, 1419, 1424, 1427, 1485, 1489,
#             1494, 1512, 1527, 1543, 1553, 1568, 1576, 1591, 1600, 1610, 1679,
#             1683, 1689, 1692, 1707, 1731, 1785, 1791, 1794, 1870, 1881, 1899,
#             1902, 1993],
#            dtype='int64')

# %%
data['Outcome'] = data['Outcome'].replace(np.NaN,0) 
data
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# 5               0      173             78             32      265  46.5
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        0
# ...

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
for i in data.columns:
        q1 = data[i].quantile(0.25)
        q3 = data[i].quantile(0.75)
        iqr = q3 - q1
        lower_limit = q1 - 1.5*iqr
        upper_limit = q3 + 1.5*iqr
        data = data[(data[i] > lower_limit)&(data[i] < upper_limit)]

# %%
data.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1630.000000  1630.000000    1630.000000    1630.000000  1630.000000
# mean      3.620859   118.676687      71.680982      21.275460    71.919018
# std       3.167097    28.757070      10.849156      15.091522    84.565227
# min       0.000000    44.000000      44.000000       0.000000     0.000000
# 25%       1.000000    99.000000      64.000000       0.000000     0.000000
# 50%       3.000000   114.000000      72.000000      24.000000    49.000000
# 75%       6.000000   136.000000      80.000000      32.000000   127.000000
# max      13.000000   198.000000     102.000000      60.000000   335.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  1630.000000               1630.000000  1630.000000  1630.000000
# mean     31.991595                  0.432763    32.183436     0.336810
# std       6.313959                  0.251398    10.600629     0.472764
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x = 'Outcome' , kind = 'count' , data = data)

# %%
# from sklearn.linear_model import Lasso
# y = data['Outcome']
# X = data.drop('Outcome', axis = 1)
# lasso = Lasso(alpha = 0.1)
# lasso.fit(X,y)
# lasso_coef = lasso.coef_
# label = X.columns
# plt.bar(label, lasso_coef)
# plt.xticks(rotation = 90)
# plt.show()

# %%
sns.pairplot(data, hue = 'Outcome')

# %%
data
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 3               0      135             68             42      250  42.3
# 5               0      173             78             32      265  46.5
# 6               4       99             72             17        0  25.6
# ...           ...      ...            ...            ...      ...   ...
# 1994            1       79             60             42       48  43.5
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        0
# ...
