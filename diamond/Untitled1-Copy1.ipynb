# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('diamonds.csv')

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
sns.pairplot(data)
plt.show()

# %%
sns.relplot(x = 'price', y = 'carat', kind = 'scatter', data = data)
plt.show()

# %%
data = data.sort_values(by = 'carat', ascending = False)
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price      x  \
# 26444       26445   4.00  Very Good     I      I1   63.3   58.0  15984  10.01
# 26534       26535   3.67    Premium     I      I1   62.4   56.0  16193   9.86
# 23644       23645   3.65       Fair     H      I1   67.1   53.0  11668   9.53
# 27679       27680   3.51    Premium     J     VS2   62.5   59.0  18701   9.66
# 24328       24329   3.50      Ideal     H      I1   62.8   57.0  12587   9.65
# ...           ...    ...        ...   ...     ...    ...    ...    ...    ...
# 31592       31593   0.20    Premium     E     VS2   59.0   60.0    367   3.81
# 31591       31592   0.20    Premium     E     VS2   59.8   62.0    367   3.79
# 31601       31602   0.20    Premium     D     VS2   61.7   60.0    367   3.77
# 14             15   0.20    Premium     E     SI2   60.2   62.0    345   3.79
# 31596       31597   0.20    Premium     F     VS2   62.6   59.0    367   3.73
#
#           y     z
# ...

# %%
data = data.drop(data.iloc[0:5,:].index)

# %%
sns.relplot(x = 'price', y = 'carat', kind = 'scatter', data = data)
plt.show()

# %%
sns.relplot(x = 'price', y = 'x', kind = 'scatter', data = data)
plt.show()

# %%
data = data[data != 0]

# %%
data[data == 0].count()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
sns.relplot(x = 'price', y = 'x', kind = 'scatter', data = data)
plt.show()

# %%
sns.relplot(x = 'price', y = 'y', kind = 'scatter', data = data)
plt.show()

# %%
data = data.sort_values(by = 'y', ascending = False)
data = data.drop(data.iloc[0:2,:].index)

# %%
sns.relplot(x = 'price', y = 'y', kind = 'scatter', data = data)
plt.show()

# %%
sns.relplot(x = 'price', y = 'z', kind = 'scatter', data = data)
plt.show()

# %%
(data['z']==0).sum()
# Out:
# 0

# %%
data = data.sort_values(by = 'z', ascending = False)
data = data.drop(data.iloc[0:1,:].index)
data = data.sort_values(by = 'z', ascending = True)
data = data.drop(data.iloc[0:3,:].index)

# %%
sns.relplot(x = 'price', y = 'z', kind = 'scatter', data = data)
plt.show()

# %%
sns.relplot(x = 'price', y = 'table', kind = 'scatter', data = data)
plt.show()

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data.dropna(axis=0)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price      x  \
# 39246       39247   0.38      Ideal     E    VVS2   60.9   56.0   1068   4.71
# 31592       31593   0.20    Premium     E     VS2   59.0   60.0    367   3.81
# 47138       47139   0.55  Very Good     E     VS2   61.0   59.0   1831   5.31
# 31591       31592   0.20    Premium     E     VS2   59.8   62.0    367   3.79
# 14             15   0.20    Premium     E     SI2   60.2   62.0    345   3.79
# ...           ...    ...        ...   ...     ...    ...    ...    ...    ...
# 26534       26535   3.67    Premium     I      I1   62.4   56.0  16193   9.86
# 26194       26195   2.01       Fair     G     SI2   65.6   56.0  15562   7.89
# 26431       26432   3.40       Fair     D      I1   66.8   52.0  15964   9.42
# 26444       26445   4.00  Very Good     I      I1   63.3   58.0  15984  10.01
# 23644       23645   3.65       Fair     H      I1   67.1   53.0  11668   9.53
#
#           y     z
# ...

# %%
for i in ["cut","color","clarity"]:    
    data_dum = pd.get_dummies(data, columns = [i])
    sns.heatmap(data_dum.corr())
    print(i)
    plt.show()
# Out:
# cut
# color
# clarity

# %%
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x = 'color', y = 'price', data = data , kind = "bar")

# %%
df_copy = data.iloc[:,:]
df_copy
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 39246       39247   0.38      Ideal     E    VVS2   60.9   56.0   1068  4.71
# 31592       31593   0.20    Premium     E     VS2   59.0   60.0    367  3.81
# 47138       47139   0.55  Very Good     E     VS2   61.0   59.0   1831  5.31
# 31591       31592   0.20    Premium     E     VS2   59.8   62.0    367  3.79
# 14             15   0.20    Premium     E     SI2   60.2   62.0    345  3.79
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 26243       26244   1.20    Premium     D    VVS1   62.1   59.0  15686   NaN
# 15951       15952   1.14       Fair     G     VS1   57.5   67.0   6381   NaN
# 11963       11964   1.00  Very Good     H     VS2   63.3   53.0   5139   NaN
# 49557       49558   0.71       Good     F     SI2   64.1   60.0   2130   NaN
# 49556       49557   0.71       Good     F     SI2   64.1   60.0   2130   NaN
#
#           y     z
# 39246  4.68  2.06
# ...

# %%
# data = data.join(df)

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 39246       39247   0.38      Ideal     E    VVS2   60.9   56.0   1068  4.71
# 31592       31593   0.20    Premium     E     VS2   59.0   60.0    367  3.81
# 47138       47139   0.55  Very Good     E     VS2   61.0   59.0   1831  5.31
# 31591       31592   0.20    Premium     E     VS2   59.8   62.0    367  3.79
# 14             15   0.20    Premium     E     SI2   60.2   62.0    345  3.79
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 26243       26244   1.20    Premium     D    VVS1   62.1   59.0  15686   NaN
# 15951       15952   1.14       Fair     G     VS1   57.5   67.0   6381   NaN
# 11963       11964   1.00  Very Good     H     VS2   63.3   53.0   5139   NaN
# 49557       49558   0.71       Good     F     SI2   64.1   60.0   2130   NaN
# 49556       49557   0.71       Good     F     SI2   64.1   60.0   2130   NaN
#
#           y     z
# 39246  4.68  2.06
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
# sns.heatmap(data[['price', 'E', 'F', 'G', 'H', 'I', 'J']].corr())

# %%
# features = price, carat , x, y, z
# target = price
# data = data.drop(['D', 'E', 'F', 'G', 'H', 'I', 'J'], axis = 1)

# %%
data = data.drop(['Unnamed: 0', 'cut', 'color', 'clarity'], axis = 1)

# %%
df = data.drop(['depth','table'], axis = 1)

# %%
df.isna().sum()
# Out:
# carat     0
# price     0
# x         8
# y         7
# z        20
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#        carat  price      x     y     z
# 39246   0.38   1068   4.71  4.68  2.06
# 31592   0.20    367   3.81  3.78  2.24
# 47138   0.55   1831   5.31  5.34  2.25
# 31591   0.20    367   3.79  3.77  2.26
# 14      0.20    345   3.79  3.75  2.27
# ...      ...    ...    ...   ...   ...
# 26534   3.67  16193   9.86  9.81  6.13
# 26194   2.01  15562   7.89  7.84  6.16
# 26431   3.40  15964   9.42  9.34  6.27
# 26444   4.00  15984  10.01  9.94  6.31
# 23644   3.65  11668   9.53  9.48  6.38
#
# [53909 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
LR = LinearRegression()
scaler = StandardScaler()

# %%
y = df['price']

# %%
X = df.drop('price', axis = 1)

# %%
y.shape
# Out:
# (53909,)

# %%
X.shape
# Out:
# (53909, 4)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 0.3, random_state = 42)

# %%
X_train.shape
# Out:
# (37736, 4)

# %%
y_train.shape
# Out:
# (37736,)

# %%
X_train
# Out:
#        carat     x     y     z
# 37453   0.35  4.58  4.54  2.77
# 39534   0.40  4.82  4.78  2.91
# 18511   1.24  6.86  6.89  4.25
# 12179   1.02  6.31  6.37  4.01
# 46764   0.53  5.23  5.18  3.20
# ...      ...   ...   ...   ...
# 34816   0.36  4.59  4.55  2.82
# 7659    1.21  6.74  6.71  4.21
# 7675    1.02  6.51  6.48  3.99
# 10041   0.26  4.07  4.10  2.53
# 42725   0.43  4.84  4.81  2.97
#
# [37736 rows x 4 columns]

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# array([[-0.9480366 , -1.03173538, -1.07711409, -1.11655984],
#        [-0.84240073, -0.81722719, -0.86100759, -0.91390855],
#        [ 0.93228192,  1.00609238,  1.03892875,  1.02575372],
#        ...,
#        [ 0.46748408,  0.69326794,  0.66974681,  0.64940134],
#        [-1.13818117, -1.48756527, -1.47330935, -1.46396204],
#        [-0.7790192 , -0.79935151, -0.83399428, -0.82705801]])

# %%
scaler.inverse_transform(X_train)
# Out:
# array([[0.35, 4.58, 4.54, 2.77],
#        [0.4 , 4.82, 4.78, 2.91],
#        [1.24, 6.86, 6.89, 4.25],
#        ...,
#        [1.02, 6.51, 6.48, 3.99],
#        [0.26, 4.07, 4.1 , 2.53],
#        [0.43, 4.84, 4.81, 2.97]])

# %%
X_test
# Out:
# array([[ 0.44635691,  0.59495169,  0.5256758 ,  0.69282662],
#        [ 0.86890039,  0.89883828,  0.84083112,  0.96785336],
#        [-0.2085855 , -0.07538639, -0.01459045, -0.05987815],
#        ...,
#        [-0.63112898, -0.5580298 , -0.62689221, -0.667832  ],
#        [-0.16633115, -0.03963502, -0.06861708,  0.08487277],
#        [ 0.42522973,  0.49663544,  0.4536403 ,  0.67835153]])

# %%
r2_cv =  cross_val_score(LR, X_train, y_train, scoring = 'r2' , cv = 5)

# %%
r2_cv.mean()
# Out:
# 0.8612979920202104

# %%
LR1 = LinearRegression()

# %%
LR1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR1.predict(X_test)

# %%
y_pred
# Out:
# array([4849.10581543, 6681.54545865, 3181.84654196, ..., 1436.12539649,
#        2773.496584  , 4853.65616942])

# %%
y_test
# Out:
# 4697     3676
# 12298    5218
# 3496     3399
# 51047    2330
# 45848    1715
#          ...
# 5389      574
# 14479    5846
# 41545    1235
# 53419    2670
# 4517     3634
# Name: price, Length: 16173, dtype: int64

# %%
sns.displot(y_pred - y_test)

# %%
X_train = scaler.inverse_transform(X_train)
X_test = scaler.inverse_transform(X_test)
y_pred
# Out:
# array([4849.10581543, 6681.54545865, 3181.84654196, ..., 1436.12539649,
#        2773.496584  , 4853.65616942])

# %%
sns.relplot(y = y_pred, x = X_test[:,0], kind = 'scatter')

# %%
sns.relplot(y = y_test, x = X_test[:,0], kind = 'scatter')

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_pred, y_test)

# %%
r2
# Out:
# 0.8341699233747613

# %%
df_copy = df_copy.drop(['depth','table'],axis = 1)

# %%
df_copy_dum = pd.get_dummies(df_copy, columns= ['cut','color','clarity'])

# %%
df_copy_dum
# Out:
#        Unnamed: 0  carat  price     x     y     z  cut_Fair  cut_Good  \
# 39246       39247   0.38   1068  4.71  4.68  2.06         0         0
# 31592       31593   0.20    367  3.81  3.78  2.24         0         0
# 47138       47139   0.55   1831  5.31  5.34  2.25         0         0
# 31591       31592   0.20    367  3.79  3.77  2.26         0         0
# 14             15   0.20    345  3.79  3.75  2.27         0         0
# ...           ...    ...    ...   ...   ...   ...       ...       ...
# 26243       26244   1.20  15686   NaN   NaN   NaN         0         0
# 15951       15952   1.14   6381   NaN   NaN   NaN         1         0
# 11963       11964   1.00   5139   NaN   NaN   NaN         0         0
# 49557       49558   0.71   2130   NaN   NaN   NaN         0         1
# 49556       49557   0.71   2130   NaN   NaN   NaN         0         1
#
#        cut_Ideal  cut_Premium  ...  color_I  color_J  clarity_I1  clarity_IF  \
# ...

# %%
df_copy_dum.isna().sum()
# Out:
# Unnamed: 0        0
# carat             0
# price             0
# x                 8
# y                 7
# z                20
# cut_Fair          0
# cut_Good          0
# cut_Ideal         0
# cut_Premium       0
# cut_Very Good     0
# color_D           0
# color_E           0
# color_F           0
# color_G           0
# color_H           0
# color_I           0
# color_J           0
# clarity_I1        0
# clarity_IF        0
# clarity_SI1       0
# clarity_SI2       0
# clarity_VS1       0
# clarity_VS2       0
# clarity_VVS1      0
# clarity_VVS2      0
# dtype: int64

# %%
df_copy_dum = df_copy_dum.dropna()
df_copy_dum.isna().sum()
df_copy_dum = df_copy_dum.drop('Unnamed: 0', axis = 1)

# %%
X_dum = df_copy_dum.drop('price', axis = 1)
y_dum = df_copy_dum['price']

# %%
X_dum_train , X_dum_test, y_dum_train, y_dum_test = train_test_split(X_dum, y_dum, random_state=42, test_size= 0.3)

# %%
X_dum_train = scaler.fit_transform(X_dum_train)
X_dum_test = scaler.transform(X_dum_test)
X_dum_train
X_dum_test
# Out:
# array([[ 0.44635691,  0.59495169,  0.5256758 , ..., -0.54415225,
#         -0.26914964, -0.3216463 ],
#        [ 0.86890039,  0.89883828,  0.84083112, ..., -0.54415225,
#         -0.26914964, -0.3216463 ],
#        [-0.2085855 , -0.07538639, -0.01459045, ..., -0.54415225,
#         -0.26914964, -0.3216463 ],
#        ...,
#        [-0.63112898, -0.5580298 , -0.62689221, ..., -0.54415225,
#         -0.26914964, -0.3216463 ],
#        [-0.16633115, -0.03963502, -0.06861708, ..., -0.54415225,
#         -0.26914964, -0.3216463 ],
#        [ 0.42522973,  0.49663544,  0.4536403 , ..., -0.54415225,
#         -0.26914964, -0.3216463 ]])

# %%
r2_cv_dum = cross_val_score(LR,X_dum_train,y_dum_train, scoring='r2', cv = 10)

# %%
r2_cv_dum.mean()
# Out:
# 0.9222606452528505

# %%
LR.fit(X_dum_train, y_dum_train)
# Out:
# LinearRegression()

# %%
y_dum_pred = LR.predict(X_dum_test)

# %%
y_dum_pred
# Out:
# array([4167.84435423, 6218.84435423, 3999.93810423, ..., 1522.67247923,
#        2878.17247923, 4481.95372923])

# %%
r2_dum = r2_score(y_dum_pred, y_dum_test)

# %%
r2_dum
# Out:
# 0.9130302412064061

# %%
r2
# Out:
# 0.8341699233747613

# %%
df_copy_dum
# Out:
#        carat  price      x     y     z  cut_Fair  cut_Good  cut_Ideal  \
# 39246   0.38   1068   4.71  4.68  2.06         0         0          1
# 31592   0.20    367   3.81  3.78  2.24         0         0          0
# 47138   0.55   1831   5.31  5.34  2.25         0         0          0
# 31591   0.20    367   3.79  3.77  2.26         0         0          0
# 14      0.20    345   3.79  3.75  2.27         0         0          0
# ...      ...    ...    ...   ...   ...       ...       ...        ...
# 26534   3.67  16193   9.86  9.81  6.13         0         0          0
# 26194   2.01  15562   7.89  7.84  6.16         1         0          0
# 26431   3.40  15964   9.42  9.34  6.27         1         0          0
# 26444   4.00  15984  10.01  9.94  6.31         0         0          0
# 23644   3.65  11668   9.53  9.48  6.38         1         0          0
#
#        cut_Premium  cut_Very Good  ...  color_I  color_J  clarity_I1  \
# ...
